# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

x, y = make_blobs(n_samples=1000, n_features=2, centers=5, random_state=6)
plt.scatter(x[:, 0], x[:, 1], c=y)
plt.show()

# %%
k=5
colors=["green","blue","red","yellow","gray"]
clusters={}
for each_cluster in range(k):
  center = 10*(2*np.random.random((x.shape[1],))-1)
  points=[]
  cluster={
      'center':center,
      'points':points,
      'color':colors[each_cluster]
  }
  cluster[each_cluster]=cluster

# %%
10*(2*np.random.random((x.shape[1],))-1)
# Out:
# array([-7.75382747,  6.01556848])

# %%
# step 2 find the distance and assigning points to the clusters
def distance(v1,v2):
  return np.sqrt(np.sum((v1-v2)**2))

# %%
#assiging every data point to one of the cliuster
#expectation step
def assignpointstocluster(cluster):
  dist=[]
  current_x=a[every_data_point]
  for every_data_point in range(x.shape[0]):
    for kx in range(k):
      d=distance(x[every_data_point],cluster[kx]['center'])
      dist.append(d)
      current_cluster=np.argmin(dist)
      clusters[current_cluster]['points'].append(x[every_data_point])

# %%
#maximization step
#update your cluster center by taking mean
def updateClusters(cluster):
  for k in range(k):
    pts=np.array(clusters[kx]['points'])
    if pts.shape[0]>0:
      # we will find out the mean
      new_u=pts.mean(axis=0)
      clusters[kx]['center']=new_u
      cluster[kx]['points']=[]

# %%
def plotcluster(cluster):
  for kx in range(kx):
    if plt.shape[0]>0:
      plt.scatter(pts[:,0],pts[:,1],color=cluster[kx]['colors'])

    plt.scatttr(clusters[kx]['center'][0],clusters[kx]['center'][1],color="black",marker='*')

# %%
assignpointstocluster(cluster)
plotcluster(cluster)
updateclusters(clusters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0fb8504610a3> in <cell line: 1>()
# ----> 1 assignpointstocluster(cluster)
#       2 plotcluster(cluster)
#
# NameError: name 'cluster' is not defined

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
